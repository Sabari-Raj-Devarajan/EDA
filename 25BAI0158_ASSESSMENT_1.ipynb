# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabari-Raj-Devarajan/EDA/blob/main/25BAI0158_ASSESSMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataFrame1 = pd.read_csv('/content/1000 Sales Records.csv')
dataFrame2 = pd.read_csv('/content/Auto.csv')

print("Columns in dataFrame1 (1000 Sales Records.csv):")
print(dataFrame1.columns)
print("\nColumns in dataFrame2 (Auto.csv):")
print(dataFrame2.columns)

vertical_concat = pd.concat([dataFrame1, dataFrame2], ignore_index=True)

print("\nVertical Concatenation:")
print(vertical_concat)

horizontal_concat = pd.concat([dataFrame1, dataFrame2], axis=1)
print("\nHorizontal Concatenation:")
print(horizontal_concat)
# Out:
# Columns in dataFrame1 (1000 Sales Records.csv):
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')
#
# Columns in dataFrame2 (Auto.csv):
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')
#
# Vertical Concatenation:
#                             Region Country   Item Type Sales Channel  \
# 0     Middle East and North Africa   Libya   Cosmetics       Offline
# 1                    North America  Canada  Vegetables        Online
# 2     Middle East and North Africa   Libya   Baby Food       Offline
# 3                             Asia   Japan      Cereal       Offline
# 4               Sub-Saharan Africa    Chad      Fruits       Offline
# ...                            ...     ...         ...           ...
# 1387                           NaN     NaN         NaN           NaN
# 1388                           NaN     NaN         NaN           NaN
# 1389                           NaN     NaN         NaN           NaN
# 1390                           NaN     NaN         NaN           NaN
# 1391                           NaN     NaN         NaN           NaN
#
#      Order Priority  Order Date     Order ID   Ship Date  Units Sold  \
# 0                 M  10/18/2014  686800706.0  10/31/2014      8446.0
# 1                 M   11/7/2011  185941302.0   12/8/2011      3018.0
# 2                 C  10/31/2016  246222341.0   12/9/2016      1517.0
# 3                 C   4/10/2010  161442649.0   5/12/2010      3322.0
# 4                 H   8/16/2011  645713555.0   8/31/2011      9845.0
# ...             ...         ...          ...         ...         ...
# 1387            NaN         NaN          NaN         NaN         NaN
# 1388            NaN         NaN          NaN         NaN         NaN
# 1389            NaN         NaN          NaN         NaN         NaN
# 1390            NaN         NaN          NaN         NaN         NaN
# 1391            NaN         NaN          NaN         NaN         NaN
#
#       Unit Price  ...  Total Profit   mpg  cylinders  displacement  \
# 0         437.20  ...    1468506.02   NaN        NaN           NaN
# 1         154.06  ...     190526.34   NaN        NaN           NaN
# 2         255.28  ...     145419.62   NaN        NaN           NaN
# 3         205.70  ...     294295.98   NaN        NaN           NaN
# 4           9.33  ...      23726.45   NaN        NaN           NaN
# ...          ...  ...           ...   ...        ...           ...
# 1387         NaN  ...           NaN  27.0        4.0         140.0
# 1388         NaN  ...           NaN  44.0        4.0          97.0
# 1389         NaN  ...           NaN  32.0        4.0         135.0
# 1390         NaN  ...           NaN  28.0        4.0         120.0
# 1391         NaN  ...           NaN  31.0        4.0         119.0
#
#       horsepower  weight  acceleration  year  origin             name
# 0            NaN     NaN           NaN   NaN     NaN              NaN
# 1            NaN     NaN           NaN   NaN     NaN              NaN
# 2            NaN     NaN           NaN   NaN     NaN              NaN
# 3            NaN     NaN           NaN   NaN     NaN              NaN
# 4            NaN     NaN           NaN   NaN     NaN              NaN
# ...          ...     ...           ...   ...     ...              ...
# 1387        86.0  2790.0          15.6  82.0     1.0  ford mustang gl
# 1388        52.0  2130.0          24.6  82.0     2.0        vw pickup
# 1389        84.0  2295.0          11.6  82.0     1.0    dodge rampage
# 1390        79.0  2625.0          18.6  82.0     1.0      ford ranger
# 1391        82.0  2720.0          19.4  82.0     1.0       chevy s-10
#
# [1392 rows x 23 columns]
#
# Horizontal Concatenation:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# 1          Online              M   11/7/2011  185941302   12/8/2011
# 2         Offline              C  10/31/2016  246222341   12/9/2016
# 3         Offline              C   4/10/2010  161442649   5/12/2010
# 4         Offline              H   8/16/2011  645713555   8/31/2011
# ..            ...            ...         ...        ...         ...
# 995       Offline              C   4/18/2010  534085166   4/25/2010
# 996       Offline              H    8/1/2011  590768182    9/7/2011
# 997        Online              C   5/12/2011  524363124   6/28/2011
# 998       Offline              L   1/25/2016  289606320   2/14/2016
# 999       Offline              C   4/10/2014  811546599    5/8/2014
#
#      Units Sold  Unit Price  ...  Total Profit   mpg  cylinders  displacement  \
# 0          8446      437.20  ...    1468506.02  18.0        8.0         307.0
# 1          3018      154.06  ...     190526.34  15.0        8.0         350.0
# 2          1517      255.28  ...     145419.62  18.0        8.0         318.0
# 3          3322      205.70  ...     294295.98  16.0        8.0         304.0
# 4          9845        9.33  ...      23726.45  17.0        8.0         302.0
# ..          ...         ...  ...           ...   ...        ...           ...
# 995        6524      152.58  ...     359733.36   NaN        NaN           NaN
# 996         288      255.28  ...      27607.68   NaN        NaN           NaN
# 997        9556      154.06  ...     603270.28   NaN        NaN           NaN
# 998        9801      668.27  ...    1624319.73   NaN        NaN           NaN
# 999        3528      205.70  ...     312545.52   NaN        NaN           NaN
#
#      horsepower  weight  acceleration  year  origin                       name
# 0         130.0  3504.0          12.0  70.0     1.0  chevrolet chevelle malibu
# 1         165.0  3693.0          11.5  70.0     1.0          buick skylark 320
# 2         150.0  3436.0          11.0  70.0     1.0         plymouth satellite
# 3         150.0  3433.0          12.0  70.0     1.0              amc rebel sst
# 4         140.0  3449.0          10.5  70.0     1.0                ford torino
# ..          ...     ...           ...   ...     ...                        ...
# 995         NaN     NaN           NaN   NaN     NaN                        NaN
# 996         NaN     NaN           NaN   NaN     NaN                        NaN
# 997         NaN     NaN           NaN   NaN     NaN                        NaN
# 998         NaN     NaN           NaN   NaN     NaN                        NaN
# 999         NaN     NaN           NaN   NaN     NaN                        NaN
#
# [1000 rows x 23 columns]

# %%
dfSE = pd.read_csv('/content/1000 Sales Records.csv')
dfML = pd.read_csv('/content/Auto.csv')

print("Columns in dfSE (1000 Sales Records.csv):")
print(dfSE.columns)
print("\nColumns in dfML (Auto.csv):")
print(dfML.columns)

print("\nCannot perform merge operations as 'StudentID' column is not found in either DataFrame.")
print("Please specify a common column for merging if you wish to proceed.")
# Out:
# Columns in dfSE (1000 Sales Records.csv):
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')
#
# Columns in dfML (Auto.csv):
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')
#
# Cannot perform merge operations as 'StudentID' column is not found in either DataFrame.
# Please specify a common column for merging if you wish to proceed.

# %%
import pandas as pd


if 'Total Revenue' in dataFrame1.columns and 'Total Cost' in dataFrame1.columns:
    dataFrame1['Gross Profit'] = dataFrame1['Total Revenue'] - dataFrame1['Total Cost']
    print("\nDataFrame1 with 'Gross Profit' column added (first 5 rows):")
    print(dataFrame1[['Total Revenue', 'Total Cost', 'Gross Profit']].head())
else:
    print("Cannot add 'Gross Profit' column: 'Total Revenue' or 'Total Cost' not found in dataFrame1.")
# Out:
# DataFrame1 with 'Gross Profit' column added (first 5 rows):
#    Total Revenue  Total Cost  Gross Profit
# 0     3692591.20  2224085.18    1468506.02
# 1      464953.08   274426.74     190526.34
# 2      387259.76   241840.14     145419.62
# 3      683335.40   389039.42     294295.98
# 4       91853.85    68127.40      23726.45

# %%
print("\nDescriptive Statistics for dataFrame1 (1000 Sales Records.csv):")
print(dataFrame1.describe())

print("\nDescriptive Statistics for dataFrame2 (Auto.csv):")
print(dataFrame2.describe())
# Out:
# Descriptive Statistics for dataFrame1 (1000 Sales Records.csv):
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# max    5.204978e+06  1.726181e+06
#
# Descriptive Statistics for dataFrame2 (Auto.csv):
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
print("\nValue Counts for 'Region' in dataFrame1:")
print(dataFrame1['Region'].value_counts())

print("\nValue Counts for 'Item Type' in dataFrame1:")
print(dataFrame1['Item Type'].value_counts())

if 'origin' in dataFrame2.columns:
    print("\nValue Counts for 'origin' in dataFrame2:")
    print(dataFrame2['origin'].value_counts())
else:
    print("Column 'origin' not found in dataFrame2.")

if 'cylinders' in dataFrame2.columns:
    print("\nValue Counts for 'cylinders' in dataFrame2:")
    print(dataFrame2['cylinders'].value_counts())
else:
    print("Column 'cylinders' not found in dataFrame2.")
# Out:
# Value Counts for 'Region' in dataFrame1:
# Region
# Europe                               267
# Sub-Saharan Africa                   262
# Middle East and North Africa         138
# Asia                                 136
# Central America and the Caribbean     99
# Australia and Oceania                 79
# North America                         19
# Name: count, dtype: int64
#
# Value Counts for 'Item Type' in dataFrame1:
# Item Type
# Beverages          101
# Vegetables          97
# Office Supplies     89
# Baby Food           87
# Personal Care       87
# Snacks              82
# Cereal              79
# Clothes             78
# Meat                78
# Household           77
# Cosmetics           75
# Fruits              70
# Name: count, dtype: int64
#
# Value Counts for 'origin' in dataFrame2:
# origin
# 1    245
# 3     79
# 2     68
# Name: count, dtype: int64
#
# Value Counts for 'cylinders' in dataFrame2:
# cylinders
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
import pandas as pd


if all(col in dataFrame1.columns for col in ['Region', 'Item Type', 'Units Sold']):

    region_item_units_sold = dataFrame1.groupby(['Region', 'Item Type'])['Units Sold'].sum()
    print("\nOriginal MultiIndex Series (Units Sold by Region and Item Type):")
    print(region_item_units_sold)


    unstacked_by_item = region_item_units_sold.unstack('Item Type')
    print("\nUnstacked by Item Type (Regions as rows, Item Types as columns):")
    print(unstacked_by_item)


    unstacked_by_region = region_item_units_sold.unstack('Region')
    print("\nUnstacked by Region (Item Types as rows, Regions as columns):")
    print(unstacked_by_region)
else:
    print("Cannot perform hierarchical indexing: Required columns ('Region', 'Item Type', 'Units Sold') not found in dataFrame1.")
# Out:
# Original MultiIndex Series (Units Sold by Region and Item Type):
# Region              Item Type
# Asia                Baby Food           55810
#                     Beverages           84400
#                     Cereal              32668
#                     Clothes             24290
#                     Cosmetics           84630
#                                         ...
# Sub-Saharan Africa  Meat               140080
#                     Office Supplies    110473
#                     Personal Care      107183
#                     Snacks              95433
#                     Vegetables         128131
# Name: Units Sold, Length: 82, dtype: int64
#
# Unstacked by Item Type (Regions as rows, Item Types as columns):
# Item Type                          Baby Food  Beverages    Cereal   Clothes  \
# Region
# Asia                                 55810.0    84400.0   32668.0   24290.0
# Australia and Oceania                21548.0    34486.0   43195.0   17020.0
# Central America and the Caribbean    35103.0    56813.0   33432.0   35999.0
# Europe                              129003.0   124509.0   95220.0  102388.0
# Middle East and North Africa         51390.0    71342.0   48643.0   78670.0
# North America                        16227.0     6947.0       NaN   28782.0
# Sub-Saharan Africa                  127537.0   126408.0  134591.0   90837.0
#
# Item Type                          Cosmetics    Fruits  Household      Meat  \
# Region
# Asia                                 84630.0   35679.0    28166.0   42192.0
# Australia and Oceania                35220.0   29951.0    55444.0   40821.0
# Central America and the Caribbean    70444.0   35469.0    26237.0   52695.0
# Europe                              116421.0   57784.0   109838.0   51713.0
# Middle East and North Africa         51522.0   46037.0    29115.0   73760.0
# North America                            NaN    4709.0     9302.0    6654.0
# Sub-Saharan Africa                   67835.0  145496.0   112890.0  140080.0
#
# Item Type                          Office Supplies  Personal Care    Snacks  \
# Region
# Asia                                       58258.0       102412.0   62402.0
# Australia and Oceania                        812.0        55362.0   35142.0
# Central America and the Caribbean          59867.0        45726.0   22471.0
# Europe                                    137140.0       110103.0  125661.0
# Middle East and North Africa               68685.0        45975.0   51392.0
# North America                               9247.0         8963.0    2643.0
# Sub-Saharan Africa                        110473.0       107183.0   95433.0
#
# Item Type                          Vegetables
# Region
# Asia                                  66617.0
# Australia and Oceania                 48297.0
# Central America and the Caribbean     29106.0
# Europe                               126028.0
# Middle East and North Africa          65832.0
# North America                          7265.0
# Sub-Saharan Africa                   128131.0
#
# Unstacked by Region (Item Types as rows, Regions as columns):
# Region               Asia  Australia and Oceania  \
# Item Type
# Baby Food         55810.0                21548.0
# Beverages         84400.0                34486.0
# Cereal            32668.0                43195.0
# Clothes           24290.0                17020.0
# Cosmetics         84630.0                35220.0
# Fruits            35679.0                29951.0
# Household         28166.0                55444.0
# Meat              42192.0                40821.0
# Office Supplies   58258.0                  812.0
# Personal Care    102412.0                55362.0
# Snacks            62402.0                35142.0
# Vegetables        66617.0                48297.0
#
# Region           Central America and the Caribbean    Europe  \
# Item Type
# Baby Food                                  35103.0  129003.0
# Beverages                                  56813.0  124509.0
# Cereal                                     33432.0   95220.0
# Clothes                                    35999.0  102388.0
# Cosmetics                                  70444.0  116421.0
# Fruits                                     35469.0   57784.0
# Household                                  26237.0  109838.0
# Meat                                       52695.0   51713.0
# Office Supplies                            59867.0  137140.0
# Personal Care                              45726.0  110103.0
# Snacks                                     22471.0  125661.0
# Vegetables                                 29106.0  126028.0
#
# Region           Middle East and North Africa  North America  \
# Item Type
# Baby Food                             51390.0        16227.0
# Beverages                             71342.0         6947.0
# Cereal                                48643.0            NaN
# Clothes                               78670.0        28782.0
# Cosmetics                             51522.0            NaN
# Fruits                                46037.0         4709.0
# Household                             29115.0         9302.0
# Meat                                  73760.0         6654.0
# Office Supplies                       68685.0         9247.0
# Personal Care                         45975.0         8963.0
# Snacks                                51392.0         2643.0
# Vegetables                            65832.0         7265.0
#
# Region           Sub-Saharan Africa
# Item Type
# Baby Food                  127537.0
# Beverages                  126408.0
# Cereal                     134591.0
# Clothes                     90837.0
# Cosmetics                   67835.0
# Fruits                     145496.0
# Household                  112890.0
# Meat                       140080.0
# Office Supplies            110473.0
# Personal Care              107183.0
# Snacks                      95433.0
# Vegetables                 128131.0

# %%
import pandas as pd


if 'Total Revenue' in dataFrame1.columns and 'Total Cost' in dataFrame1.columns:
    revenue_series = dataFrame1['Total Revenue'].head(10)
    cost_series = dataFrame1['Total Cost'].head(10)


    combined_finances = pd.concat([revenue_series, cost_series], keys=['Revenue', 'Cost'])
    print("\nCombined Revenue and Cost Series (first 10 rows, with hierarchical keys):")
    print(combined_finances)


    print("\nUnstacked Combined Finances:")
    print(combined_finances.unstack())
else:
    print("Cannot perform series concatenation: 'Total Revenue' or 'Total Cost' not found in dataFrame1.")
# Out:
# Combined Revenue and Cost Series (first 10 rows, with hierarchical keys):
# Revenue  0    3692591.20
#          1     464953.08
#          2     387259.76
#          3     683335.40
#          4      91853.85
#          5    1959909.60
#          6     585010.80
#          7     797634.72
#          8     374057.68
#          9     739488.00
# Cost     0    2224085.18
#          1     274426.74
#          2     241840.14
#          3     389039.42
#          4      68127.40
#          5    1115824.08
#          6     333060.84
#          7     261596.16
#          8     220778.04
#          9     436464.00
# dtype: float64
#
# Unstacked Combined Finances:
#                   0          1          2          3         4           5  \
# Revenue  3692591.20  464953.08  387259.76  683335.40  91853.85  1959909.60
# Cost     2224085.18  274426.74  241840.14  389039.42  68127.40  1115824.08
#
#                  6          7          8         9
# Revenue  585010.80  797634.72  374057.68  739488.0
# Cost     333060.84  261596.16  220778.04  436464.0
